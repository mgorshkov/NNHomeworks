# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils import mnist, plot_graphs

# %%
train_loader, test_loader = mnist()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %%
class Net(nn.Module):
    def __init__(self, log_softmax=False):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 10)
        self.log_softmax = log_softmax
        self.optim = optim.SGD(self.parameters(), lr=1e-4)
        
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = self.fc3(x)
        if self.log_softmax:
            x = F.log_softmax(x, dim=1)
        else:
            x = torch.log(F.softmax(x, dim=1))
        return x
    
    def loss(self, output, target, **kwargs):
        self._loss = F.nll_loss(output, target, **kwargs)
        return self._loss

# %%
def train(epoch, models):
    for batch_idx, (data, target) in enumerate(train_loader):
        for name, model in models.items():
            model.optim.zero_grad()
            output = model(data)
            loss = model.loss(output, target)
            loss.backward()
            model.optim.step()
            
        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        print(line + losses)

# %%
models = {'F.softmax': Net(), 'log_softmax': Net(True)}
test_log = {k: [] for k in models}

# %%
avg_lambda = lambda l: 'Loss: {:.4f}'.format(l)
acc_lambda = lambda c, p: 'Accuracy: {}/{} ({:.0f}%)'.format(c, len(test_loader.dataset), p)
line = lambda i, l, c, p: '{}: '.format(i) + avg_lambda(l) + '\t' + acc_lambda(c, p)

def test(models, log=None):
    test_size = len(test_loader.sampler)
    test_loss = {k: 0. for k in models}
    correct = {k: 0. for k in models}
    with torch.no_grad():
        for data, target in test_loader:
            for k, m in models.items():
                output = m(data)
                test_loss[k] += m.loss(output, target, reduction='sum').item() # sum up batch loss
                pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
                correct[k] += pred.eq(target.data.view_as(pred)).cpu().sum()
    
    for k in models.keys():
        test_loss[k] /= test_size
    correct_pct = {k: 100. * correct[k] / test_size for k in correct}
    lines = '\n'.join([line(k, test_loss[k], correct[k], correct_pct[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines
    if log is not None:
        for k in models.keys():
            log[k].append((test_loss[k], correct_pct[k]))
    print(report)

# %%
for epoch in range(1, 11):
    train(epoch, models)
    test(models, test_log)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Losses F.softmax: 2.333026 log_softmax: 2.328404
# Train Epoch: 1 [10000/60000 (17%)]	Losses F.softmax: 2.304454 log_softmax: 2.351367
# Train Epoch: 1 [20000/60000 (33%)]	Losses F.softmax: 2.307875 log_softmax: 2.265439
# Train Epoch: 1 [30000/60000 (50%)]	Losses F.softmax: 2.324386 log_softmax: 2.350862
# Train Epoch: 1 [40000/60000 (67%)]	Losses F.softmax: 2.304071 log_softmax: 2.339390
# Train Epoch: 1 [50000/60000 (83%)]	Losses F.softmax: 2.301562 log_softmax: 2.306597
# Train Epoch: 1 [60000/60000 (100%)]	Losses F.softmax: 2.291391 log_softmax: 2.295553
# Test set:
# F.softmax: Loss: 2.3008	Accuracy: 1491.0/10000 (15%)
# log_softmax: Loss: 2.3104	Accuracy: 1032.0/10000 (10%)
#
# Train Epoch: 2 [0/60000 (0%)]	Losses F.softmax: 2.300987 log_softmax: 2.286285
# Train Epoch: 2 [10000/60000 (17%)]	Losses F.softmax: 2.308978 log_softmax: 2.310853
# Train Epoch: 2 [20000/60000 (33%)]	Losses F.softmax: 2.304718 log_softmax: 2.280292
# Train Epoch: 2 [30000/60000 (50%)]	Losses F.softmax: 2.310131 log_softmax: 2.273998
# Train Epoch: 2 [40000/60000 (67%)]	Losses F.softmax: 2.296815 log_softmax: 2.288868
# Train Epoch: 2 [50000/60000 (83%)]	Losses F.softmax: 2.284885 log_softmax: 2.303061
# Train Epoch: 2 [60000/60000 (100%)]	Losses F.softmax: 2.316368 log_softmax: 2.296470
# Test set:
# F.softmax: Loss: 2.2981	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.3018	Accuracy: 1033.0/10000 (10%)
#
# Train Epoch: 3 [0/60000 (0%)]	Losses F.softmax: 2.296727 log_softmax: 2.285732
# Train Epoch: 3 [10000/60000 (17%)]	Losses F.softmax: 2.309059 log_softmax: 2.328654
# Train Epoch: 3 [20000/60000 (33%)]	Losses F.softmax: 2.296937 log_softmax: 2.298130
# Train Epoch: 3 [30000/60000 (50%)]	Losses F.softmax: 2.293021 log_softmax: 2.287011
# Train Epoch: 3 [40000/60000 (67%)]	Losses F.softmax: 2.285923 log_softmax: 2.301630
# Train Epoch: 3 [50000/60000 (83%)]	Losses F.softmax: 2.303977 log_softmax: 2.309642
# Train Epoch: 3 [60000/60000 (100%)]	Losses F.softmax: 2.293938 log_softmax: 2.292717
# Test set:
# F.softmax: Loss: 2.2969	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2995	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 4 [0/60000 (0%)]	Losses F.softmax: 2.305903 log_softmax: 2.304682
# Train Epoch: 4 [10000/60000 (17%)]	Losses F.softmax: 2.285794 log_softmax: 2.290565
# Train Epoch: 4 [20000/60000 (33%)]	Losses F.softmax: 2.271071 log_softmax: 2.278073
# Train Epoch: 4 [30000/60000 (50%)]	Losses F.softmax: 2.291282 log_softmax: 2.298041
# Train Epoch: 4 [40000/60000 (67%)]	Losses F.softmax: 2.300282 log_softmax: 2.307116
# Train Epoch: 4 [50000/60000 (83%)]	Losses F.softmax: 2.296619 log_softmax: 2.297969
# Train Epoch: 4 [60000/60000 (100%)]	Losses F.softmax: 2.287869 log_softmax: 2.296207
# Test set:
# F.softmax: Loss: 2.2959	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2985	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 5 [0/60000 (0%)]	Losses F.softmax: 2.303762 log_softmax: 2.307209
# Train Epoch: 5 [10000/60000 (17%)]	Losses F.softmax: 2.298058 log_softmax: 2.301145
# Train Epoch: 5 [20000/60000 (33%)]	Losses F.softmax: 2.290362 log_softmax: 2.293832
# Train Epoch: 5 [30000/60000 (50%)]	Losses F.softmax: 2.297202 log_softmax: 2.298881
# Train Epoch: 5 [40000/60000 (67%)]	Losses F.softmax: 2.287158 log_softmax: 2.293271
# Train Epoch: 5 [50000/60000 (83%)]	Losses F.softmax: 2.297085 log_softmax: 2.300046
# Train Epoch: 5 [60000/60000 (100%)]	Losses F.softmax: 2.292979 log_softmax: 2.295559
# Test set:
# F.softmax: Loss: 2.2951	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2977	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 6 [0/60000 (0%)]	Losses F.softmax: 2.282607 log_softmax: 2.284015
# Train Epoch: 6 [10000/60000 (17%)]	Losses F.softmax: 2.287938 log_softmax: 2.290831
# Train Epoch: 6 [20000/60000 (33%)]	Losses F.softmax: 2.294213 log_softmax: 2.297894
# Train Epoch: 6 [30000/60000 (50%)]	Losses F.softmax: 2.276582 log_softmax: 2.281159
# Train Epoch: 6 [40000/60000 (67%)]	Losses F.softmax: 2.289483 log_softmax: 2.293697
# Train Epoch: 6 [50000/60000 (83%)]	Losses F.softmax: 2.286089 log_softmax: 2.288405
# Train Epoch: 6 [60000/60000 (100%)]	Losses F.softmax: 2.307951 log_softmax: 2.310151
# Test set:
# F.softmax: Loss: 2.2942	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2969	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 7 [0/60000 (0%)]	Losses F.softmax: 2.302798 log_softmax: 2.306454
# Train Epoch: 7 [10000/60000 (17%)]	Losses F.softmax: 2.292887 log_softmax: 2.297302
# Train Epoch: 7 [20000/60000 (33%)]	Losses F.softmax: 2.286775 log_softmax: 2.290576
# Train Epoch: 7 [30000/60000 (50%)]	Losses F.softmax: 2.293599 log_softmax: 2.294115
# Train Epoch: 7 [40000/60000 (67%)]	Losses F.softmax: 2.297950 log_softmax: 2.300780
# Train Epoch: 7 [50000/60000 (83%)]	Losses F.softmax: 2.290828 log_softmax: 2.292508
# Train Epoch: 7 [60000/60000 (100%)]	Losses F.softmax: 2.293250 log_softmax: 2.294258
# Test set:
# F.softmax: Loss: 2.2934	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2962	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 8 [0/60000 (0%)]	Losses F.softmax: 2.293472 log_softmax: 2.294087
# Train Epoch: 8 [10000/60000 (17%)]	Losses F.softmax: 2.287197 log_softmax: 2.292655
# Train Epoch: 8 [20000/60000 (33%)]	Losses F.softmax: 2.284487 log_softmax: 2.284699
# Train Epoch: 8 [30000/60000 (50%)]	Losses F.softmax: 2.298967 log_softmax: 2.300688
# Train Epoch: 8 [40000/60000 (67%)]	Losses F.softmax: 2.304962 log_softmax: 2.305878
# Train Epoch: 8 [50000/60000 (83%)]	Losses F.softmax: 2.271166 log_softmax: 2.274892
# Train Epoch: 8 [60000/60000 (100%)]	Losses F.softmax: 2.284669 log_softmax: 2.287928
# Test set:
# F.softmax: Loss: 2.2925	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2954	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 9 [0/60000 (0%)]	Losses F.softmax: 2.311130 log_softmax: 2.310872
# Train Epoch: 9 [10000/60000 (17%)]	Losses F.softmax: 2.300766 log_softmax: 2.302266
# Train Epoch: 9 [20000/60000 (33%)]	Losses F.softmax: 2.302455 log_softmax: 2.305467
# Train Epoch: 9 [30000/60000 (50%)]	Losses F.softmax: 2.284279 log_softmax: 2.286795
# Train Epoch: 9 [40000/60000 (67%)]	Losses F.softmax: 2.286130 log_softmax: 2.289412
# Train Epoch: 9 [50000/60000 (83%)]	Losses F.softmax: 2.297989 log_softmax: 2.299222
# Train Epoch: 9 [60000/60000 (100%)]	Losses F.softmax: 2.299805 log_softmax: 2.300276
# Test set:
# F.softmax: Loss: 2.2917	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2946	Accuracy: 1135.0/10000 (11%)
#
# Train Epoch: 10 [0/60000 (0%)]	Losses F.softmax: 2.314759 log_softmax: 2.318385
# Train Epoch: 10 [10000/60000 (17%)]	Losses F.softmax: 2.289125 log_softmax: 2.293267
# Train Epoch: 10 [20000/60000 (33%)]	Losses F.softmax: 2.301482 log_softmax: 2.302212
# Train Epoch: 10 [30000/60000 (50%)]	Losses F.softmax: 2.301740 log_softmax: 2.302129
# Train Epoch: 10 [40000/60000 (67%)]	Losses F.softmax: 2.283862 log_softmax: 2.285401
# Train Epoch: 10 [50000/60000 (83%)]	Losses F.softmax: 2.278910 log_softmax: 2.281370
# Train Epoch: 10 [60000/60000 (100%)]	Losses F.softmax: 2.300164 log_softmax: 2.304627
# Test set:
# F.softmax: Loss: 2.2908	Accuracy: 1135.0/10000 (11%)
# log_softmax: Loss: 2.2938	Accuracy: 1135.0/10000 (11%)

# %%
plot_graphs(test_log, 'loss')

# %%
plot_graphs(test_log, 'accuracy')

# %%
test_log
# Out:
# {'F.softmax': [(2.300801170349121, tensor(14.9100)),
#   (2.298148207092285, tensor(11.3500)),
#   (2.296874924468994, tensor(11.3500)),
#   (2.295943187713623, tensor(11.3500)),
#   (2.2950742240905764, tensor(11.3500)),
#   (2.294212865447998, tensor(11.3500)),
#   (2.2933764183044434, tensor(11.3500)),
#   (2.2925359367370604, tensor(11.3500)),
#   (2.2916807815551756, tensor(11.3500)),
#   (2.290818647003174, tensor(11.3500))],
#  'log_softmax': [(2.3103711952209474, tensor(10.3200)),
#   (2.3017579887390136, tensor(10.3300)),
#   (2.2995300186157226, tensor(11.3500)),
#   (2.2985433555603025, tensor(11.3500)),
#   (2.2977212989807128, tensor(11.3500)),
#   (2.2969280960083007, tensor(11.3500)),
#   (2.296152828216553, tensor(11.3500)),
#   (2.295371549987793, tensor(11.3500)),
#   (2.2945752883911132, tensor(11.3500)),
#   (2.2937734153747558, tensor(11.3500))]}
